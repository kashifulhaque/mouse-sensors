# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
password = os.getenv('password')

# %%
import numpy as np
import pandas as pd

# %%
# Load the .csv file
data = pd.read_csv('../data/mouse-sensors.csv')

# %%
data.head(10)
# Out:
#          Brand      Mouse     Sensor  PollingRate     Hand  Weight
# 0     Atompalm   Hydrogen   PMW 3360         8000  Ambidex      48  \
# 1   Zaunkoenig        M2K   PMW 3360         8000  Ambidex      24
# 2        Razer   Viper 8k     Focus+         8000  Ambidex      71
# 3        Zowie       ZA11   PMW 3310         1000  Ambidex      90
# 4      Genesis  Xenon 770   PAW 3327         1000    Right     110
# 5      Genesis  Xenon 800   PAW 3389         1000    Right      58
# 6  endgamegear        XM1   PMW 3389         1000  Ambidex      70
# 7  endgamegear       XM1r   PMW 3370         1000  Ambidex      70
# 8     Mountain  Makalu 67   PMW 3370         1000    Right      67
# 9        Ninox     Aurora  ADNS 3090         1000  Ambidex      70
#
#    ExtraButtons    L   W   H
# 0             2  124  65  40
# 1             0   79  60  29
# 2             5  127  58  38
# 3             4  128  67  40
# 4             4  128  69  39
# 5             4  120  66  43
# ...

# %%
data.columns = ['Brand', 'Mouse', 'Sensor', 'Polling Rate (Hz)', 'Hand', 'Weight (g)', 'Extra Buttons', 'L (mm)', 'W (mm)', 'H (mm)']

# %%
data.head(10)
# Out:
#          Brand      Mouse     Sensor  Polling Rate (Hz)     Hand  Weight (g)
# 0     Atompalm   Hydrogen   PMW 3360               8000  Ambidex          48  \
# 1   Zaunkoenig        M2K   PMW 3360               8000  Ambidex          24
# 2        Razer   Viper 8k     Focus+               8000  Ambidex          71
# 3        Zowie       ZA11   PMW 3310               1000  Ambidex          90
# 4      Genesis  Xenon 770   PAW 3327               1000    Right         110
# 5      Genesis  Xenon 800   PAW 3389               1000    Right          58
# 6  endgamegear        XM1   PMW 3389               1000  Ambidex          70
# 7  endgamegear       XM1r   PMW 3370               1000  Ambidex          70
# 8     Mountain  Makalu 67   PMW 3370               1000    Right          67
# 9        Ninox     Aurora  ADNS 3090               1000  Ambidex          70
#
#    Extra Buttons  L (mm)  W (mm)  H (mm)
# 0              2     124      65      40
# ...

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = f'mongodb+srv://mongodb:{password}@cluster-ap-south-1.rzpcloa.mongodb.net/?retryWrites=true&w=majority'

# %%
client = MongoClient(uri, server_api = ServerApi('1'))

try:
  client.admin.command('ping')
  print(f'Pinged deployment, successfully connected to MongoDB')
except Exception as e:
  print(e)
# Out:
# Pinged deployment, successfully connected to MongoDB

# %%
db = client['mouse_db']
collection = db['mouse_collection']

# %%
data_dict = data.to_dict('records')

# %%
collection.insert_many(data_dict)
